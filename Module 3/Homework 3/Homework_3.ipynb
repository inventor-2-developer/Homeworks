# %%
#importing pandas
import pandas as pd
data=pd.read_csv('ratings_and_sentiments.csv')
#Dropping columns not needed
dz=data.drop(columns=['vibe_sent','rating','cat_rating','bool_HIGH','tea_sent','service_sent','price_sent','parking_sent','food_sent','local_sent','internet_sent','hours_sent','alcohol_sent','seating_sent','location_sent','coffee_sent'])
#Creating the Dataframe
df=pd.DataFrame(dz)
df
# Out:
#                      coffee_shop_name  \
# 0     The Factory - Cafe With a Soul
# 1     The Factory - Cafe With a Soul
# 2     The Factory - Cafe With a Soul
# 3     The Factory - Cafe With a Soul
# 4     The Factory - Cafe With a Soul
# ...                               ...
# 7611               The Steeping Room
# 7612               The Steeping Room
# 7613               The Steeping Room
# 7614               The Steeping Room
# 7615               The Steeping Room
#
#                                             review_text  num_rating  \
# 0     11/25/2016 1 check-in Love love loved the vibe...           5
# 1     12/2/2016 Listed in Date Night: Austin, vibe i...           4
# 2     11/30/2016 1 check-in Listed in food seating I...           4
# 3     11/25/2016 Very cool vibe! Good drinks Nice se...           2
# 4     12/3/2016 1 check-in They are location within ...           4
# ...                                                 ...         ...
# ...

# %%
#Returning all of the shops that have number rating greater than or equal to 4
df[df['num_rating']>=4]
# Out:
#                      coffee_shop_name  \
# 0     The Factory - Cafe With a Soul
# 1     The Factory - Cafe With a Soul
# 2     The Factory - Cafe With a Soul
# 4     The Factory - Cafe With a Soul
# 5     The Factory - Cafe With a Soul
# ...                               ...
# 7610               The Steeping Room
# 7611               The Steeping Room
# 7612               The Steeping Room
# 7613               The Steeping Room
# 7615               The Steeping Room
#
#                                             review_text  num_rating  \
# 0     11/25/2016 1 check-in Love love loved the vibe...           5
# 1     12/2/2016 Listed in Date Night: Austin, vibe i...           4
# 2     11/30/2016 1 check-in Listed in food seating I...           4
# 4     12/3/2016 1 check-in They are location within ...           4
# 5     11/20/2016 1 check-in Very cute cafe! I think ...           4
# ...                                                 ...         ...
# ...

# %%
#Returning all of the shops that have an overall sentiment greater than or equal to 4
df[df['overall_sent']>=4]
# Out:
#                           coffee_shop_name  \
# 0          The Factory - Cafe With a Soul
# 233              Mozart's Coffee Roasters
# 931                Venezia Italian Gelato
# 1101       The Factory - Cafe With a Soul
# 1466             Figure 8 Coffee Purveyors
# 1591               MaГ±ana Coffee & Juice
# 2008       The Factory - Cafe With a Soul
# 2213                    Flat Track Coffee
# 2595               Flightpath Coffeehouse
# 2681  Third Coast Coffee Roasting Company
# 2831                           Dolce Neve
# 3051                              Halcyon
# 3106       The Factory - Cafe With a Soul
# 3390            Arturo's Underground Cafe
# 3425            Arturo's Underground Cafe
# 3787                     Lucky Lab Coffee
# 4137                              Halcyon
# 4419                             Tea Haus
# 4515                  Friends & Neighbors
# 4530                    Sorrento's Coffee
# 4576                    Sorrento's Coffee
# ...

# %%
#Finding the number of the shops that have an overall sentiment greater than or equal to 4 and number rating greater than 4
dp=df[(df['overall_sent']>=4)&(df['num_rating']>4)]
print("There are " + f"{dp['coffee_shop_name'].count()}" " " +"coffee shops in this list.")
# Out:
# There are 24 coffee shops in this list.

# %%
# Changing the names of the review text column to comments and the overall sent to sentiment rating
rename_df=dp.rename(columns={'review_text':'comments','overall_sent':'sentiment_rating'})
rename_df
# Out:
#                           coffee_shop_name  \
# 0          The Factory - Cafe With a Soul
# 233              Mozart's Coffee Roasters
# 931                Venezia Italian Gelato
# 1101       The Factory - Cafe With a Soul
# 1466             Figure 8 Coffee Purveyors
# 1591               MaГ±ana Coffee & Juice
# 2008       The Factory - Cafe With a Soul
# 2213                    Flat Track Coffee
# 2595               Flightpath Coffeehouse
# 2681  Third Coast Coffee Roasting Company
# 2831                           Dolce Neve
# 3106       The Factory - Cafe With a Soul
# 3390            Arturo's Underground Cafe
# 3425            Arturo's Underground Cafe
# 3787                     Lucky Lab Coffee
# 4419                             Tea Haus
# 4515                  Friends & Neighbors
# 4530                    Sorrento's Coffee
# 4771               Venezia Italian Gelato
# 5612                        Dominican Joe
# 6428          Strange Brew, Austin Coffee
# ...

# %%
df.to_csv('new_file.csv', sep='\t', index=False)
